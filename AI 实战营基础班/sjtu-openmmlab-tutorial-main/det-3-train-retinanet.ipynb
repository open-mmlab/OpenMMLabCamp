# %% [markdown]
# # Train Detectors
#
# In this notebook we will train an detector using MMDetection.

# %% [markdown]
# ## Prepare the Dataset
#
# We have already prepared a dataset, a tiny subset from the KITTI autonomous driving datset.
#
# Our task is to detect pedestrian, cars, etc from street view images.
#
# To download and extract the dataset, in command line:
#
# ```
# curl https://download.openmmlab.com/mmdetection/data/kitti_tiny.zip -o kitti_tiny.zip
# unzip -d data kitti_tiny.zip
# ```
#
# The dataset contain *image files*, *label files* and *train/test splits*.

# %% [markdown]
# ## Format the Dataset

# %% [markdown]
# Definition of Kitti annotation can be found [here](https://github.com/bostondiditeam/kitti/blob/master/resources/devkit_object/readme.txt#L46).
#
# To train with MMDetection, we need to generate an annotation file with the following format.
#
# ```python
# [
#     {
#         'filename': 'a.jpg',
#         'width': 1280,
#         'height': 720,
#         'ann': {
#             'bboxes': <np.ndarray, float32> (n, 4),
#             'labels': <np.ndarray, int64> (n, ),
#             'bboxes_ignore': <np.ndarray, float32> (k, 4),
#             'labels_ignore': <np.ndarray, int64> (k, ) (optional field)
#         }
#     },
#     ...
# ]
# ```

# %%
import mmcv
import numpy as np

CLASSES = []
data_infos = []

for idx in range(75):
    imfile = f"data/kitti_tiny/training/image_2/{idx:06d}.jpeg"
    annfile = f"data/kitti_tiny/training/label_2/{idx:06d}.txt"

    image = mmcv.imread(imfile)
    height, width = image.shape[:2]

    ann = mmcv.list_from_file(annfile)

    gt_bboxes = []
    gt_labels = []
    gt_bboxes_ignore = []

    for line in ann:
        line = line.split(' ')
        bbox = [float(line[i]) for i in range(4,8)]
        
        if line[0] == 'DontCare':
            gt_bboxes_ignore.append(bbox)
        else:
            gt_bboxes.append(bbox)
            if line[0] not in CLASSES:
                CLASSES.append(line[0])
            gt_labels.append(CLASSES.index(line[0]))

    data_infos.append(
        dict(
            filename=f"{idx:06d}.jpeg",
            width=width,
            height=height,
            ann = dict(
                bboxes=np.array(gt_bboxes, dtype=np.float32).reshape(-1,4),
                labels=np.array(gt_labels, dtype=np.int64).reshape(-1),
                bboxes_ignore=np.array(gt_bboxes_ignore, dtype=np.float32).reshape(-1,4),
            )
    ))
    
print(CLASSES)
mmcv.dump(data_infos[:50], 'data/kitti_tiny/train_ann.pkl')
mmcv.dump(data_infos[50:], 'data/kitti_tiny/test_ann.pkl')
# Out:
# ['Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram', 'Person_sitting']

# %% [markdown]
# ## Prepare a Config and Checkpoint File
#
# We choose to use RetinaNet.
#
# Use mim to download the config file and checkpoint file.
#
# ```
# mim download mmcls --config retinanet_r18_fpn_1x_coco --dest .
# mv retinanet_r18_fpn_1x_coco.py retinanet_r18_fpn_1x_kitti.py
# ```
#
# If you prefer to play with other models, navigate to [MMDetection model zoo](https://github.com/open-mmlab/mmdetection#overview-of-benchmark-and-model-zoo).

# %%
# !mim download mmdet --config retinanet_r18_fpn_1x_coco --dest .
# Out:
# processing retinanet_r18_fpn_1x_coco...
# retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth exists in C:\wangruohui\桌面\sjtu-openmmlab-tutorial
# Successfully dumped retinanet_r18_fpn_1x_coco.py to C:\wangruohui\桌面\sjtu-openmmlab-tutorial
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# ## Modify the Config File
#
# 1. Remove some intermediate item for clean: `dataset_type`, `img_norm_cfg`, `train_pipeline`, `test_pipeline`
# 1. Modify model
#     1. number of class in `bbox_head`: from 80 to 8
#     2. `inif_cfg`: to None
#     3. `load_from`: to the checkpoint we downloaded
# 1. Data: for train/val/test
#     1. `type`: `CocoDataset` -> `CustomDataset`
#     2. `prefix`, which is the root path to images: modify to `"data/kitti_tiny/training/image_2/"`
#     3. `ann_file`, the pickle file we just generates: modify to `data/kitti_tiny/train_ann.pkl` for training subset and `data/kitti_tiny/val_ann.pkl` for validation / test subset
#     4. `evaluation.metric`: to `'mAP'`, which is designed for `CustomDataset`
# 1. Runner and Optimizer
#     1. `optimizer.lr`: decrease learning rates based on linear scaling rule and for fine-tuning.
#     1. `lr_config`, decrease `warmup_iters` as we don't have that much iters for small dataset.
# 1. Misc
#     1. Decrease `log_confg.interval` for more logs
#     1. Increase `checkpoint_config.interval` to avoid saving too many checkpoints, to save time and disk space

# %% [markdown]
# ## Launch Training
#
# In command line
#
# ```
# mim train mmdet retinanet_r18_fpn_1x_kitti.py
# ```

# %%
# !mim train mmdet retinanet_r18_fpn_1x_kitti.py
# Out:
# Training command is python c:\users\wangruohui\miniconda3\envs\mm\lib\site-packages\mmdet\.mim\tools\train.py retinanet_r18_fpn_1x_kitti.py --gpus 1 --launcher none.
# [                                                  ] 0/25, elapsed: 0s, ETA:
# [>                                 ] 1/25, 0.2 task/s, elapsed: 4s, ETA:    98s
# [>>                                ] 2/25, 0.5 task/s, elapsed: 4s, ETA:    48s
# [>>>>                              ] 3/25, 0.7 task/s, elapsed: 4s, ETA:    31s
# [>>>>>                             ] 4/25, 0.9 task/s, elapsed: 4s, ETA:    22s
# [>>>>>>                            ] 5/25, 1.2 task/s, elapsed: 4s, ETA:    17s
# [>>>>>>>>                          ] 6/25, 1.4 task/s, elapsed: 4s, ETA:    14s
# [>>>>>>>>>                         ] 7/25, 1.6 task/s, elapsed: 4s, ETA:    11s
# [>>>>>>>>>>                        ] 8/25, 1.8 task/s, elapsed: 5s, ETA:    10s
# [>>>>>>>>>>>>                      ] 9/25, 2.0 task/s, elapsed: 5s, ETA:     8s
# [>>>>>>>>>>>>>                    ] 10/25, 2.2 task/s, elapsed: 5s, ETA:     7s
# [>>>>>>>>>>>>>>                   ] 11/25, 2.3 task/s, elapsed: 5s, ETA:     6s
# [>>>>>>>>>>>>>>>                  ] 12/25, 2.5 task/s, elapsed: 5s, ETA:     5s
# [>>>>>>>>>>>>>>>>>                ] 13/25, 2.7 task/s, elapsed: 5s, ETA:     4s
# [>>>>>>>>>>>>>>>>>>               ] 14/25, 2.9 task/s, elapsed: 5s, ETA:     4s
# [>>>>>>>>>>>>>>>>>>>              ] 15/25, 3.0 task/s, elapsed: 5s, ETA:     3s
# [>>>>>>>>>>>>>>>>>>>>>            ] 16/25, 3.2 task/s, elapsed: 5s, ETA:     3s
# [>>>>>>>>>>>>>>>>>>>>>>           ] 17/25, 3.4 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>          ] 18/25, 3.5 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>        ] 19/25, 3.7 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>       ] 20/25, 3.8 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>      ] 21/25, 4.0 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 22/25, 4.1 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 23/25, 4.3 task/s, elapsed: 5s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 24/25, 4.4 task/s, elapsed: 5s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 4.5 task/s, elapsed: 6s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# [                                                  ] 0/25, elapsed: 0s, ETA:
# [>                                 ] 1/25, 0.2 task/s, elapsed: 4s, ETA:   102s
# [>>                                ] 2/25, 0.5 task/s, elapsed: 4s, ETA:    50s
# [>>>>                              ] 3/25, 0.7 task/s, elapsed: 4s, ETA:    32s
# [>>>>>                             ] 4/25, 0.9 task/s, elapsed: 4s, ETA:    23s
# [>>>>>>                            ] 5/25, 1.1 task/s, elapsed: 5s, ETA:    18s
# [>>>>>>>>                          ] 6/25, 1.3 task/s, elapsed: 5s, ETA:    15s
# [>>>>>>>>>                         ] 7/25, 1.5 task/s, elapsed: 5s, ETA:    12s
# [>>>>>>>>>>                        ] 8/25, 1.7 task/s, elapsed: 5s, ETA:    10s
# [>>>>>>>>>>>>                      ] 9/25, 1.9 task/s, elapsed: 5s, ETA:     8s
# [>>>>>>>>>>>>>                    ] 10/25, 2.1 task/s, elapsed: 5s, ETA:     7s
# [>>>>>>>>>>>>>>                   ] 11/25, 2.3 task/s, elapsed: 5s, ETA:     6s
# [>>>>>>>>>>>>>>>                  ] 12/25, 2.4 task/s, elapsed: 5s, ETA:     5s
# [>>>>>>>>>>>>>>>>>                ] 13/25, 2.6 task/s, elapsed: 5s, ETA:     5s
# [>>>>>>>>>>>>>>>>>>               ] 14/25, 2.8 task/s, elapsed: 5s, ETA:     4s
# [>>>>>>>>>>>>>>>>>>>              ] 15/25, 2.9 task/s, elapsed: 5s, ETA:     3s
# [>>>>>>>>>>>>>>>>>>>>>            ] 16/25, 3.1 task/s, elapsed: 5s, ETA:     3s
# [>>>>>>>>>>>>>>>>>>>>>>           ] 17/25, 3.2 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>          ] 18/25, 3.4 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>        ] 19/25, 3.5 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>       ] 20/25, 3.7 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>      ] 21/25, 3.8 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 22/25, 4.0 task/s, elapsed: 6s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 23/25, 4.1 task/s, elapsed: 6s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 24/25, 4.2 task/s, elapsed: 6s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 4.4 task/s, elapsed: 6s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# [                                                  ] 0/25, elapsed: 0s, ETA:
# [>                                 ] 1/25, 0.2 task/s, elapsed: 4s, ETA:    99s
# [>>                                ] 2/25, 0.5 task/s, elapsed: 4s, ETA:    48s
# [>>>>                              ] 3/25, 0.7 task/s, elapsed: 4s, ETA:    31s
# [>>>>>                             ] 4/25, 0.9 task/s, elapsed: 4s, ETA:    23s
# [>>>>>>                            ] 5/25, 1.1 task/s, elapsed: 4s, ETA:    18s
# [>>>>>>>>                          ] 6/25, 1.3 task/s, elapsed: 4s, ETA:    14s
# [>>>>>>>>>                         ] 7/25, 1.5 task/s, elapsed: 5s, ETA:    12s
# [>>>>>>>>>>                        ] 8/25, 1.7 task/s, elapsed: 5s, ETA:    10s
# [>>>>>>>>>>>>                      ] 9/25, 1.9 task/s, elapsed: 5s, ETA:     8s
# [>>>>>>>>>>>>>                    ] 10/25, 2.1 task/s, elapsed: 5s, ETA:     7s
# [>>>>>>>>>>>>>>                   ] 11/25, 2.3 task/s, elapsed: 5s, ETA:     6s
# [>>>>>>>>>>>>>>>                  ] 12/25, 2.5 task/s, elapsed: 5s, ETA:     5s
# [>>>>>>>>>>>>>>>>>                ] 13/25, 2.7 task/s, elapsed: 5s, ETA:     5s
# [>>>>>>>>>>>>>>>>>>               ] 14/25, 2.8 task/s, elapsed: 5s, ETA:     4s
# [>>>>>>>>>>>>>>>>>>>              ] 15/25, 3.0 task/s, elapsed: 5s, ETA:     3s
# [>>>>>>>>>>>>>>>>>>>>>            ] 16/25, 3.2 task/s, elapsed: 5s, ETA:     3s
# [>>>>>>>>>>>>>>>>>>>>>>           ] 17/25, 3.3 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>          ] 18/25, 3.5 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>        ] 19/25, 3.6 task/s, elapsed: 5s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>       ] 20/25, 3.8 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>      ] 21/25, 3.9 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 22/25, 4.1 task/s, elapsed: 5s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 23/25, 4.2 task/s, elapsed: 5s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 24/25, 4.3 task/s, elapsed: 6s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 4.5 task/s, elapsed: 6s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# Training finished successfully.
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\mmdet\utils\setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\mmdet\utils\setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# c:\users\wangruohui\miniconda3\envs\mm\lib\site-packages\mmdet\.mim\tools\train.py:155: UserWarning: `--gpus` is deprecated because we only support single GPU mode in non-distributed training. Use `gpus=1` now.
#   warnings.warn('`--gpus` is deprecated because we only support '
# 2022-10-08 17:03:57,565 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: win32
# Python: 3.8.13 (default, Mar 28 2022, 06:59:08) [MSC v.1916 64 bit (AMD64)]
# CUDA available: True
# GPU 0: NVIDIA GeForce GTX 1660 SUPER
# CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.3
# NVCC: Cuda compilation tools, release 11.3, V11.3.109
# MSVC: 用于 x64 的 Microsoft (R) C/C++ 优化编译器 19.29.30146 版
# GCC: n/a
# PyTorch: 1.11.0
# PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192829337
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.5.2 (Git Hash a9302535553c73243c632ad3c4c80beec3d19a1e)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.2
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /w /bigobj -DUSE_PTHREADPOOL -openmp:experimental -IC:/cb/pytorch_1000000000000/work/mkl/include -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.11.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.12.0
# OpenCV: 4.5.4
# MMCV: 1.6.1
# MMCV Compiler: MSVC 192930140
# MMCV CUDA Compiler: 11.3
# MMDetection: 2.25.2+f614772
# ------------------------------------------------------------
#
# 2022-10-08 17:03:57,825 - mmdet - INFO - Distributed training: False
# 2022-10-08 17:03:58,033 - mmdet - INFO - Config:
# model = dict(
#     type='RetinaNet',
#     backbone=dict(
#         type='ResNet',
#         depth=18,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch'),
#     neck=dict(
#         type='FPN',
#         in_channels=[64, 128, 256, 512],
#         out_channels=256,
#         start_level=1,
#         add_extra_convs='on_input',
#         num_outs=5),
#     bbox_head=dict(
#         type='RetinaHead',
#         num_classes=8,
#         in_channels=256,
#         stacked_convs=4,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             octave_base_scale=4,
#             scales_per_octave=3,
#             ratios=[0.5, 1.0, 2.0],
#             strides=[8, 16, 32, 64, 128]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='FocalLoss',
#             use_sigmoid=True,
#             gamma=2.0,
#             alpha=0.25,
#             loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     train_cfg=dict(
#         assigner=dict(
#             type='MaxIoUAssigner',
#             pos_iou_thr=0.5,
#             neg_iou_thr=0.4,
#             min_pos_iou=0,
#             ignore_iof_thr=-1),
#         allowed_border=-1,
#         pos_weight=-1,
#         debug=False),
#     test_cfg=dict(
#         nms_pre=1000,
#         min_bbox_size=0,
#         score_thr=0.05,
#         nms=dict(type='nms', iou_threshold=0.5),
#         max_per_img=100))
# load_from = 'retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth'
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CustomDataset',
#         ann_file='data/kitti_tiny/train_ann.pkl',
#         img_prefix='data/kitti_tiny/training/image_2',
#         classes=[
#             'Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram',
#             'Person_sitting'
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CustomDataset',
#         ann_file='data/kitti_tiny/test_ann.pkl',
#         img_prefix='data/kitti_tiny/training/image_2',
#         classes=[
#             'Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram',
#             'Person_sitting'
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CustomDataset',
#         ann_file='data/kitti_tiny/test_ann.pkl',
#         img_prefix='data/kitti_tiny/training/image_2',
#         classes=[
#             'Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram',
#             'Person_sitting'
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=4, metric='mAP')
# optimizer = dict(type='SGD', lr=0.001, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=50,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=12)
# log_config = dict(interval=5, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# work_dir = './work_dirs\retinanet_r18_fpn_1x_kitti'
# auto_resume = False
# gpu_ids = range(0, 1)
#
# 2022-10-08 17:03:58,033 - mmdet - INFO - Set random seed to 167806033, deterministic: False
# 2022-10-08 17:03:58,190 - mmdet - INFO - initialize ResNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2022-10-08 17:03:58,266 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,267 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,268 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,269 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,270 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,271 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,273 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,275 - mmdet - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2022-10-08 17:03:58,284 - mmdet - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2022-10-08 17:03:58,309 - mmdet - INFO - initialize RetinaHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'retina_cls', 'std': 0.01, 'bias_prob': 0.01}}
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\mmdet\datasets\custom.py:179: UserWarning: CustomDataset does not support filtering empty gt images.
#   warnings.warn(
# 2022-10-08 17:03:58,516 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2022-10-08 17:03:58,536 - mmdet - INFO - load checkpoint from local path: retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth
# 2022-10-08 17:03:58,662 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.retina_cls.weight: copying a param with shape torch.Size([720, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([72, 256, 3, 3]).
# size mismatch for bbox_head.retina_cls.bias: copying a param with shape torch.Size([720]) from checkpoint, the shape in current model is torch.Size([72]).
# 2022-10-08 17:03:58,668 - mmdet - INFO - Start running, host: wangruohui@CN0214008399W, work_dir: C:\wangruohui\桌面\sjtu-openmmlab-tutorial\work_dirs\retinanet_r18_fpn_1x_kitti
# 2022-10-08 17:03:58,668 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-10-08 17:03:58,668 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2022-10-08 17:03:58,668 - mmdet - INFO - Checkpoints will be saved to C:\wangruohui\桌面\sjtu-openmmlab-tutorial\work_dirs\retinanet_r18_fpn_1x_kitti by HardDiskBackend.
# 2022-10-08 17:04:14,203 - mmdet - INFO - Epoch [1][5/25]	lr: 8.092e-05, eta: 0:15:09, time: 3.082, data_time: 2.315, memory: 727, loss_cls: 1.1365, loss_bbox: 0.2291, loss: 1.3656
# 2022-10-08 17:04:15,437 - mmdet - INFO - Epoch [1][10/25]	lr: 1.808e-04, eta: 0:08:02, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 1.1310, loss_bbox: 0.2427, loss: 1.3736
# 2022-10-08 17:04:16,670 - mmdet - INFO - Epoch [1][15/25]	lr: 2.807e-04, eta: 0:05:39, time: 0.245, data_time: 0.026, memory: 727, loss_cls: 1.0562, loss_bbox: 0.3140, loss: 1.3702
# 2022-10-08 17:04:17,897 - mmdet - INFO - Epoch [1][20/25]	lr: 3.806e-04, eta: 0:04:27, time: 0.245, data_time: 0.027, memory: 727, loss_cls: 0.9428, loss_bbox: 0.2241, loss: 1.1669
# 2022-10-08 17:04:19,125 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:04:19,125 - mmdet - INFO - Epoch [1][25/25]	lr: 4.805e-04, eta: 0:03:43, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.8722, loss_bbox: 0.1962, loss: 1.0684
# 2022-10-08 17:04:31,083 - mmdet - INFO - Epoch [2][5/25]	lr: 5.804e-04, eta: 0:04:45, time: 2.281, data_time: 2.019, memory: 727, loss_cls: 0.5434, loss_bbox: 0.2325, loss: 0.7760
# 2022-10-08 17:04:32,313 - mmdet - INFO - Epoch [2][10/25]	lr: 6.803e-04, eta: 0:04:09, time: 0.246, data_time: 0.027, memory: 727, loss_cls: 0.4810, loss_bbox: 0.2545, loss: 0.7354
# 2022-10-08 17:04:33,542 - mmdet - INFO - Epoch [2][15/25]	lr: 7.802e-04, eta: 0:03:42, time: 0.246, data_time: 0.027, memory: 727, loss_cls: 0.6132, loss_bbox: 0.1729, loss: 0.7860
# 2022-10-08 17:04:34,771 - mmdet - INFO - Epoch [2][20/25]	lr: 8.801e-04, eta: 0:03:20, time: 0.246, data_time: 0.027, memory: 727, loss_cls: 0.4917, loss_bbox: 0.2508, loss: 0.7425
# 2022-10-08 17:04:35,999 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:04:35,999 - mmdet - INFO - Epoch [2][25/25]	lr: 9.800e-04, eta: 0:03:03, time: 0.246, data_time: 0.027, memory: 727, loss_cls: 0.4041, loss_bbox: 0.1727, loss: 0.5768
# 2022-10-08 17:04:47,384 - mmdet - INFO - Epoch [3][5/25]	lr: 1.000e-03, eta: 0:03:32, time: 2.192, data_time: 1.937, memory: 727, loss_cls: 0.4153, loss_bbox: 0.1746, loss: 0.5899
# 2022-10-08 17:04:48,614 - mmdet - INFO - Epoch [3][10/25]	lr: 1.000e-03, eta: 0:03:15, time: 0.246, data_time: 0.027, memory: 727, loss_cls: 0.3760, loss_bbox: 0.2091, loss: 0.5851
# 2022-10-08 17:04:49,847 - mmdet - INFO - Epoch [3][15/25]	lr: 1.000e-03, eta: 0:03:01, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.3549, loss_bbox: 0.2025, loss: 0.5575
# 2022-10-08 17:04:51,077 - mmdet - INFO - Epoch [3][20/25]	lr: 1.000e-03, eta: 0:02:48, time: 0.246, data_time: 0.027, memory: 727, loss_cls: 0.4325, loss_bbox: 0.2463, loss: 0.6788
# 2022-10-08 17:04:52,310 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:04:52,310 - mmdet - INFO - Epoch [3][25/25]	lr: 1.000e-03, eta: 0:02:37, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.3503, loss_bbox: 0.1578, loss: 0.5081
# 2022-10-08 17:05:03,894 - mmdet - INFO - Epoch [4][5/25]	lr: 1.000e-03, eta: 0:02:55, time: 2.232, data_time: 1.950, memory: 727, loss_cls: 0.3921, loss_bbox: 0.1928, loss: 0.5849
# 2022-10-08 17:05:05,129 - mmdet - INFO - Epoch [4][10/25]	lr: 1.000e-03, eta: 0:02:44, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2934, loss_bbox: 0.1884, loss: 0.4817
# 2022-10-08 17:05:06,367 - mmdet - INFO - Epoch [4][15/25]	lr: 1.000e-03, eta: 0:02:34, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.3290, loss_bbox: 0.1930, loss: 0.5220
# 2022-10-08 17:05:07,603 - mmdet - INFO - Epoch [4][20/25]	lr: 1.000e-03, eta: 0:02:25, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2215, loss_bbox: 0.1752, loss: 0.3966
# 2022-10-08 17:05:08,838 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:05:08,839 - mmdet - INFO - Epoch [4][25/25]	lr: 1.000e-03, eta: 0:02:17, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2356, loss_bbox: 0.1996, loss: 0.4353
# 2022-10-08 17:05:19,424 - mmdet - INFO -
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 510  | 0.923  | 0.813 |
# | Truck          | 3   | 312  | 1.000  | 0.524 |
# | Car            | 62  | 1037 | 0.984  | 0.812 |
# | Cyclist        | 7   | 41   | 0.000  | 0.000 |
# | Misc           | 1   | 89   | 0.000  | 0.000 |
# | Van            | 11  | 400  | 0.909  | 0.205 |
# | Tram           | 5   | 58   | 0.000  | 0.000 |
# | Person_sitting | 5   | 2    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.294 |
# +----------------+-----+------+--------+-------+
# 2022-10-08 17:05:19,458 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:05:19,458 - mmdet - INFO - Epoch(val) [4][25]	AP50: 0.2940, mAP: 0.2942
# 2022-10-08 17:05:30,644 - mmdet - INFO - Epoch [5][5/25]	lr: 1.000e-03, eta: 0:02:28, time: 2.212, data_time: 1.933, memory: 727, loss_cls: 0.2216, loss_bbox: 0.1867, loss: 0.4083
# 2022-10-08 17:05:31,879 - mmdet - INFO - Epoch [5][10/25]	lr: 1.000e-03, eta: 0:02:19, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2959, loss_bbox: 0.1573, loss: 0.4532
# 2022-10-08 17:05:33,113 - mmdet - INFO - Epoch [5][15/25]	lr: 1.000e-03, eta: 0:02:12, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.1844, loss_bbox: 0.1900, loss: 0.3744
# 2022-10-08 17:05:34,348 - mmdet - INFO - Epoch [5][20/25]	lr: 1.000e-03, eta: 0:02:05, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2301, loss_bbox: 0.1909, loss: 0.4210
# 2022-10-08 17:05:35,581 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:05:35,581 - mmdet - INFO - Epoch [5][25/25]	lr: 1.000e-03, eta: 0:01:58, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2543, loss_bbox: 0.1321, loss: 0.3865
# 2022-10-08 17:05:46,963 - mmdet - INFO - Epoch [6][5/25]	lr: 1.000e-03, eta: 0:02:05, time: 2.190, data_time: 1.930, memory: 727, loss_cls: 0.2092, loss_bbox: 0.1861, loss: 0.3953
# 2022-10-08 17:05:48,195 - mmdet - INFO - Epoch [6][10/25]	lr: 1.000e-03, eta: 0:01:58, time: 0.246, data_time: 0.027, memory: 727, loss_cls: 0.1830, loss_bbox: 0.1157, loss: 0.2986
# 2022-10-08 17:05:49,429 - mmdet - INFO - Epoch [6][15/25]	lr: 1.000e-03, eta: 0:01:52, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2339, loss_bbox: 0.1161, loss: 0.3499
# 2022-10-08 17:05:50,663 - mmdet - INFO - Epoch [6][20/25]	lr: 1.000e-03, eta: 0:01:46, time: 0.247, data_time: 0.028, memory: 727, loss_cls: 0.1306, loss_bbox: 0.1850, loss: 0.3156
# 2022-10-08 17:05:51,900 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:05:51,901 - mmdet - INFO - Epoch [6][25/25]	lr: 1.000e-03, eta: 0:01:40, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.2060, loss_bbox: 0.2000, loss: 0.4060
# 2022-10-08 17:06:03,263 - mmdet - INFO - Epoch [7][5/25]	lr: 1.000e-03, eta: 0:01:44, time: 2.188, data_time: 1.925, memory: 727, loss_cls: 0.2059, loss_bbox: 0.1692, loss: 0.3751
# 2022-10-08 17:06:04,498 - mmdet - INFO - Epoch [7][10/25]	lr: 1.000e-03, eta: 0:01:38, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.1503, loss_bbox: 0.1438, loss: 0.2941
# 2022-10-08 17:06:05,732 - mmdet - INFO - Epoch [7][15/25]	lr: 1.000e-03, eta: 0:01:33, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.1950, loss_bbox: 0.1167, loss: 0.3117
# 2022-10-08 17:06:06,968 - mmdet - INFO - Epoch [7][20/25]	lr: 1.000e-03, eta: 0:01:28, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.1827, loss_bbox: 0.1469, loss: 0.3296
# 2022-10-08 17:06:08,206 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:06:08,206 - mmdet - INFO - Epoch [7][25/25]	lr: 1.000e-03, eta: 0:01:23, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 0.2490, loss_bbox: 0.2153, loss: 0.4643
# 2022-10-08 17:06:19,568 - mmdet - INFO - Epoch [8][5/25]	lr: 1.000e-03, eta: 0:01:24, time: 2.188, data_time: 1.921, memory: 727, loss_cls: 0.1988, loss_bbox: 0.1112, loss: 0.3100
# 2022-10-08 17:06:20,802 - mmdet - INFO - Epoch [8][10/25]	lr: 1.000e-03, eta: 0:01:19, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.1185, loss_bbox: 0.1295, loss: 0.2480
# 2022-10-08 17:06:22,042 - mmdet - INFO - Epoch [8][15/25]	lr: 1.000e-03, eta: 0:01:15, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 0.1736, loss_bbox: 0.1697, loss: 0.3432
# 2022-10-08 17:06:23,282 - mmdet - INFO - Epoch [8][20/25]	lr: 1.000e-03, eta: 0:01:10, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 0.2336, loss_bbox: 0.2001, loss: 0.4337
# 2022-10-08 17:06:24,518 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:06:24,518 - mmdet - INFO - Epoch [8][25/25]	lr: 1.000e-03, eta: 0:01:06, time: 0.247, data_time: 0.027, memory: 727, loss_cls: 0.1791, loss_bbox: 0.1554, loss: 0.3346
# 2022-10-08 17:06:35,591 - mmdet - INFO -
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 482  | 0.923  | 0.786 |
# | Truck          | 3   | 298  | 1.000  | 0.686 |
# | Car            | 62  | 705  | 0.968  | 0.783 |
# | Cyclist        | 7   | 211  | 0.143  | 0.003 |
# | Misc           | 1   | 81   | 0.000  | 0.000 |
# | Van            | 11  | 297  | 0.909  | 0.299 |
# | Tram           | 5   | 146  | 0.400  | 0.027 |
# | Person_sitting | 5   | 3    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.323 |
# +----------------+-----+------+--------+-------+
# 2022-10-08 17:06:35,625 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:06:35,625 - mmdet - INFO - Epoch(val) [8][25]	AP50: 0.3230, mAP: 0.3229
# 2022-10-08 17:06:46,744 - mmdet - INFO - Epoch [9][5/25]	lr: 1.000e-04, eta: 0:01:06, time: 2.198, data_time: 1.935, memory: 727, loss_cls: 0.1167, loss_bbox: 0.1344, loss: 0.2511
# 2022-10-08 17:06:47,989 - mmdet - INFO - Epoch [9][10/25]	lr: 1.000e-04, eta: 0:01:01, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1390, loss_bbox: 0.1459, loss: 0.2848
# 2022-10-08 17:06:49,233 - mmdet - INFO - Epoch [9][15/25]	lr: 1.000e-04, eta: 0:00:57, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1942, loss_bbox: 0.1221, loss: 0.3163
# 2022-10-08 17:06:50,479 - mmdet - INFO - Epoch [9][20/25]	lr: 1.000e-04, eta: 0:00:53, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1929, loss_bbox: 0.1843, loss: 0.3771
# 2022-10-08 17:06:51,728 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:06:51,728 - mmdet - INFO - Epoch [9][25/25]	lr: 1.000e-04, eta: 0:00:49, time: 0.250, data_time: 0.027, memory: 727, loss_cls: 0.1392, loss_bbox: 0.1466, loss: 0.2858
# 2022-10-08 17:07:03,247 - mmdet - INFO - Epoch [10][5/25]	lr: 1.000e-04, eta: 0:00:48, time: 2.214, data_time: 1.944, memory: 727, loss_cls: 0.1740, loss_bbox: 0.1332, loss: 0.3072
# 2022-10-08 17:07:04,490 - mmdet - INFO - Epoch [10][10/25]	lr: 1.000e-04, eta: 0:00:44, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 0.1108, loss_bbox: 0.1629, loss: 0.2737
# 2022-10-08 17:07:05,733 - mmdet - INFO - Epoch [10][15/25]	lr: 1.000e-04, eta: 0:00:40, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1110, loss_bbox: 0.1129, loss: 0.2238
# 2022-10-08 17:07:06,983 - mmdet - INFO - Epoch [10][20/25]	lr: 1.000e-04, eta: 0:00:36, time: 0.250, data_time: 0.027, memory: 727, loss_cls: 0.1675, loss_bbox: 0.1766, loss: 0.3441
# 2022-10-08 17:07:08,227 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:07:08,227 - mmdet - INFO - Epoch [10][25/25]	lr: 1.000e-04, eta: 0:00:32, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1641, loss_bbox: 0.1013, loss: 0.2654
# 2022-10-08 17:07:19,574 - mmdet - INFO - Epoch [11][5/25]	lr: 1.000e-04, eta: 0:00:30, time: 2.187, data_time: 1.921, memory: 727, loss_cls: 0.1261, loss_bbox: 0.1422, loss: 0.2683
# 2022-10-08 17:07:20,815 - mmdet - INFO - Epoch [11][10/25]	lr: 1.000e-04, eta: 0:00:27, time: 0.247, data_time: 0.026, memory: 727, loss_cls: 0.1536, loss_bbox: 0.1371, loss: 0.2907
# 2022-10-08 17:07:22,058 - mmdet - INFO - Epoch [11][15/25]	lr: 1.000e-04, eta: 0:00:23, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1631, loss_bbox: 0.1298, loss: 0.2929
# 2022-10-08 17:07:23,302 - mmdet - INFO - Epoch [11][20/25]	lr: 1.000e-04, eta: 0:00:19, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1395, loss_bbox: 0.1205, loss: 0.2600
# 2022-10-08 17:07:24,546 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:07:24,546 - mmdet - INFO - Epoch [11][25/25]	lr: 1.000e-04, eta: 0:00:16, time: 0.249, data_time: 0.027, memory: 727, loss_cls: 0.1319, loss_bbox: 0.1185, loss: 0.2505
# 2022-10-08 17:07:36,053 - mmdet - INFO - Epoch [12][5/25]	lr: 1.000e-05, eta: 0:00:13, time: 2.215, data_time: 1.934, memory: 727, loss_cls: 0.1544, loss_bbox: 0.1373, loss: 0.2917
# 2022-10-08 17:07:37,295 - mmdet - INFO - Epoch [12][10/25]	lr: 1.000e-05, eta: 0:00:10, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 0.1406, loss_bbox: 0.1250, loss: 0.2656
# 2022-10-08 17:07:38,542 - mmdet - INFO - Epoch [12][15/25]	lr: 1.000e-05, eta: 0:00:06, time: 0.250, data_time: 0.027, memory: 727, loss_cls: 0.1661, loss_bbox: 0.1654, loss: 0.3315
# 2022-10-08 17:07:39,785 - mmdet - INFO - Epoch [12][20/25]	lr: 1.000e-05, eta: 0:00:03, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 0.1484, loss_bbox: 0.1454, loss: 0.2938
# 2022-10-08 17:07:41,027 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:07:41,027 - mmdet - INFO - Epoch [12][25/25]	lr: 1.000e-05, eta: 0:00:00, time: 0.248, data_time: 0.027, memory: 727, loss_cls: 0.1417, loss_bbox: 0.1069, loss: 0.2487
# 2022-10-08 17:07:41,331 - mmdet - INFO - Saving checkpoint at 12 epochs
# 2022-10-08 17:07:52,920 - mmdet - INFO -
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 506  | 0.923  | 0.792 |
# | Truck          | 3   | 176  | 1.000  | 0.833 |
# | Car            | 62  | 698  | 0.984  | 0.786 |
# | Cyclist        | 7   | 267  | 0.286  | 0.010 |
# | Misc           | 1   | 83   | 0.000  | 0.000 |
# | Van            | 11  | 260  | 0.909  | 0.346 |
# | Tram           | 5   | 146  | 0.400  | 0.026 |
# | Person_sitting | 5   | 3    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.349 |
# +----------------+-----+------+--------+-------+
# 2022-10-08 17:07:52,954 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti.py
# 2022-10-08 17:07:52,954 - mmdet - INFO - Epoch(val) [12][25]	AP50: 0.3490, mAP: 0.3491
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# ## Understand Logs
#
#
# The log is long but mainly contains the following parts:
#
# 1. Toolbox information
# 2. Dumped Config files
# 3. Model Initialization Logs
#     1. Check `mmdet - INFO - load checkpoint from local path: retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth`, which means pretrained weights are loaded correctly.
# 4. Information on Hooks: we don't configure this explicitly in this tutorial, so ignore that
# 5. Training progress
#     1. Training logs: including current learning, training loss, time consumption, memory occupation
#     2. Validation logs: meanAP on validation set
# ```

# %% [markdown]
# ## Test the Model
#
# The trained model (checkpoint file) is usually saved under `work_dirs/{experiment_name}/latest.pth`.
# We can load it to test with a new image.

# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot

image = 'data/kitti_tiny/training/image_2/000066.jpeg'
model = init_detector('retinanet_r18_fpn_1x_kitti.py', 'work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth')
result = inference_detector(model, image)
show_result_pyplot(model, image, result)
# Out:
# load checkpoint from local path: work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\mmdet\datasets\utils.py:66: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(

# %%
# !mim test mmdet retinanet_r18_fpn_1x_kitti.py --checkpoint work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth --eval mAP
# !mim test mmdet retinanet_r18_fpn_1x_kitti.py --checkpoint work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth --show-dir work_dirs
# Out:
# Testing command is python c:\users\wangruohui\miniconda3\envs\mm\lib\site-packages\mmdet\.mim\tools\test.py retinanet_r18_fpn_1x_kitti.py work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth --launcher none --show-dir work_dirs.
# load checkpoint from local path: work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth
# [                                                  ] 0/25, elapsed: 0s, ETA:
# [>                                 ] 1/25, 0.2 task/s, elapsed: 6s, ETA:   155s
# [>>                                ] 2/25, 0.3 task/s, elapsed: 7s, ETA:    77s
# [>>>>                              ] 3/25, 0.4 task/s, elapsed: 7s, ETA:    50s
# [>>>>>                             ] 4/25, 0.6 task/s, elapsed: 7s, ETA:    37s
# [>>>>>>                            ] 5/25, 0.7 task/s, elapsed: 7s, ETA:    29s
# [>>>>>>>>                          ] 6/25, 0.8 task/s, elapsed: 7s, ETA:    24s
# [>>>>>>>>>                         ] 7/25, 0.9 task/s, elapsed: 8s, ETA:    20s
# [>>>>>>>>>>                        ] 8/25, 1.0 task/s, elapsed: 8s, ETA:    17s
# [>>>>>>>>>>>>                      ] 9/25, 1.1 task/s, elapsed: 8s, ETA:    14s
# [>>>>>>>>>>>>>                    ] 10/25, 1.2 task/s, elapsed: 8s, ETA:    12s
# [>>>>>>>>>>>>>>                   ] 11/25, 1.3 task/s, elapsed: 8s, ETA:    11s
# [>>>>>>>>>>>>>>>                  ] 12/25, 1.4 task/s, elapsed: 9s, ETA:     9s
# [>>>>>>>>>>>>>>>>>                ] 13/25, 1.5 task/s, elapsed: 9s, ETA:     8s
# [>>>>>>>>>>>>>>>>>>               ] 14/25, 1.6 task/s, elapsed: 9s, ETA:     7s
# [>>>>>>>>>>>>>>>>>>>              ] 15/25, 1.7 task/s, elapsed: 9s, ETA:     6s
# [>>>>>>>>>>>>>>>>>>>>>            ] 16/25, 1.7 task/s, elapsed: 9s, ETA:     5s
# [>>>>>>>>>>>>>>>>>>>>>>           ] 17/25, 1.8 task/s, elapsed: 9s, ETA:     4s
# [>>>>>>>>>>>>>>>>>>>>>>>         ] 18/25, 1.9 task/s, elapsed: 10s, ETA:     4s
# [>>>>>>>>>>>>>>>>>>>>>>>>        ] 19/25, 1.9 task/s, elapsed: 10s, ETA:     3s
# [>>>>>>>>>>>>>>>>>>>>>>>>>       ] 20/25, 2.0 task/s, elapsed: 10s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>      ] 21/25, 2.1 task/s, elapsed: 10s, ETA:     2s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 22/25, 2.2 task/s, elapsed: 10s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 23/25, 2.2 task/s, elapsed: 10s, ETA:     1s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 24/25, 2.3 task/s, elapsed: 11s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 2.3 task/s, elapsed: 11s, ETA:     0sTesting finished successfully.
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\mmdet\utils\setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\mmdet\utils\setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
